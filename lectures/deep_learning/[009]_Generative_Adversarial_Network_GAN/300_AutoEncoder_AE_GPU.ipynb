# %% [markdown]
# # AutoEncoder(AE)
#
# * 입력데이터의 차원축소를 통해 의미있는 잠재 공간(Latent Space/Manifold)을 학습
#  - Encoder 학습을 위해 Decoder를 사용

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # I. Load MNIST Dataset

# %% [markdown]
# > ## 1) X_train and X_test

# %%
from tensorflow.keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
X_train.shape, X_test.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %% [markdown]
# > ## 2) Normalization and Reshape

# %%
X_train = X_train / 255.
X_test = X_test / 255.

X_train = X_train.reshape(60000, 28 * 28)
X_test = X_test.reshape(10000, 28 * 28)

# %%
X_train.shape, X_test.shape
# Out:
# ((60000, 784), (10000, 784))

# %% [markdown]
# # II. Keras Modeling with Functional API

# %% [markdown]
# > ## 1) 'Latent Space' Size

# %%
encoding_dim = 3

# %% [markdown]
# > ## 2) Encoder
#
# * Input

# %%
from tensorflow.keras import layers

input_img = layers.Input(shape = (784, ))

# %% [markdown]
# * Encoding Layers and Encoding Model

# %%
encoded = layers.Dense(256, activation = 'elu')(input_img)
encoded = layers.Dense(128, activation = 'elu')(encoded)
encoded = layers.Dense(encoding_dim, activation = 'elu')(encoded)

# %% [markdown]
# > ## 3) Decoder
#
# * Decoding Lyaers and Decoding Model

# %%
decoded = layers.Dense(128, activation = 'elu')(encoded)
decoded = layers.Dense(256, activation = 'elu')(decoded)
decoded = layers.Dense(784, activation = 'sigmoid')(decoded)

# %% [markdown]
# # III. AutoEncoder Model

# %% [markdown]
# > ## 1) 'autoencoder' Model

# %%
from tensorflow.keras import models

autoencoder = models.Model(input_img, decoded)

# %%
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense (Dense)               (None, 256)               200960
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 3)                 387
#
#  dense_3 (Dense)             (None, 128)               512
#
#  dense_4 (Dense)             (None, 256)               33024
#
#  dense_5 (Dense)             (None, 784)               201488
#
# =================================================================
# Total params: 469,267
# Trainable params: 469,267
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) 'encoder' Model

# %%
encoder = models.Model(input_img, encoded)

# %%
encoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense (Dense)               (None, 256)               200960
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 234,243
# Trainable params: 234,243
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 3) 'decoder' Model

# %%
encoded_input = layers.Input(shape = (encoding_dim,))

decoder_layer = autoencoder.layers[-3](encoded_input)
decoder_layer = autoencoder.layers[-2](decoder_layer)
decoder_layer = autoencoder.layers[-1](decoder_layer)

decoder = models.Model(encoded_input, decoder_layer)

# %%
decoder.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 3)]               0
#
#  dense_3 (Dense)             (None, 128)               512
#
#  dense_4 (Dense)             (None, 256)               33024
#
#  dense_5 (Dense)             (None, 784)               201488
#
# =================================================================
# Total params: 235,024
# Trainable params: 235,024
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # IV. Model Fit

# %% [markdown]
# > ## 1) Model Compile

# %%
autoencoder.compile(loss = 'binary_crossentropy',
                    optimizer = 'adam')

# %% [markdown]
# > ## 2) Model Training
#
# * 약 2분

# %%
# %%time

autoencoder.fit(X_train, X_train,
                epochs = 60,
                batch_size = 256,
                validation_data = (X_test, X_test))
# Out:
# Epoch 1/60
# 235/235 [==============================] - 8s 10ms/step - loss: 0.2632 - val_loss: 0.2330
# Epoch 2/60
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2199 - val_loss: 0.2111
# Epoch 3/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2061 - val_loss: 0.2032
# Epoch 4/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2003 - val_loss: 0.1989
# Epoch 5/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1958 - val_loss: 0.1941
# Epoch 6/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1924 - val_loss: 0.1910
# Epoch 7/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1892 - val_loss: 0.1877
# Epoch 8/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1859 - val_loss: 0.1841
# Epoch 9/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1789 - val_loss: 0.1746
# Epoch 10/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1725 - val_loss: 0.1704
# Epoch 11/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1693 - val_loss: 0.1684
# Epoch 12/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1672 - val_loss: 0.1664
# Epoch 13/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1656 - val_loss: 0.1651
# Epoch 14/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1643 - val_loss: 0.1643
# Epoch 15/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1632 - val_loss: 0.1632
# Epoch 16/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1623 - val_loss: 0.1627
# Epoch 17/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1614 - val_loss: 0.1616
# Epoch 18/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1607 - val_loss: 0.1614
# Epoch 19/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1600 - val_loss: 0.1607
# Epoch 20/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1594 - val_loss: 0.1602
# Epoch 21/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1589 - val_loss: 0.1600
# Epoch 22/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1583 - val_loss: 0.1594
# Epoch 23/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1579 - val_loss: 0.1591
# Epoch 24/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1574 - val_loss: 0.1588
# Epoch 25/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1570 - val_loss: 0.1584
# Epoch 26/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1566 - val_loss: 0.1579
# Epoch 27/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1562 - val_loss: 0.1579
# Epoch 28/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1559 - val_loss: 0.1578
# Epoch 29/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1556 - val_loss: 0.1571
# Epoch 30/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1553 - val_loss: 0.1570
# Epoch 31/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1550 - val_loss: 0.1571
# Epoch 32/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1547 - val_loss: 0.1565
# Epoch 33/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1545 - val_loss: 0.1566
# Epoch 34/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1542 - val_loss: 0.1565
# Epoch 35/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1540 - val_loss: 0.1564
# Epoch 36/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1537 - val_loss: 0.1561
# Epoch 37/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1535 - val_loss: 0.1561
# Epoch 38/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1533 - val_loss: 0.1558
# Epoch 39/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1531 - val_loss: 0.1561
# Epoch 40/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1529 - val_loss: 0.1557
# Epoch 41/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1527 - val_loss: 0.1559
# Epoch 42/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1525 - val_loss: 0.1555
# Epoch 43/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1523 - val_loss: 0.1554
# Epoch 44/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1521 - val_loss: 0.1553
# Epoch 45/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1519 - val_loss: 0.1551
# Epoch 46/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1517 - val_loss: 0.1551
# Epoch 47/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1516 - val_loss: 0.1548
# Epoch 48/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1514 - val_loss: 0.1545
# Epoch 49/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1513 - val_loss: 0.1551
# Epoch 50/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1511 - val_loss: 0.1548
# Epoch 51/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1510 - val_loss: 0.1550
# Epoch 52/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1508 - val_loss: 0.1546
# Epoch 53/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1507 - val_loss: 0.1545
# Epoch 54/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1506 - val_loss: 0.1544
# Epoch 55/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1504 - val_loss: 0.1546
# Epoch 56/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1502 - val_loss: 0.1545
# Epoch 57/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1501 - val_loss: 0.1543
# Epoch 58/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1500 - val_loss: 0.1543
# Epoch 59/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1499 - val_loss: 0.1542
# Epoch 60/60
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1497 - val_loss: 0.1544
# CPU times: user 1min 7s, sys: 6.15 s, total: 1min 13s
# Wall time: 1min 25s

# %% [markdown]
# # V. Model Predict

# %% [markdown]
# > ## 1) Imgae Encoding
#
# * Create 'Latent Space'

# %%
encoded_imgs = encoder.predict(X_test)

encoded_imgs.shape
# Out:
# 313/313 [==============================] - 0s 1ms/step
# (10000, 3)

# %% [markdown]
# > ## 2) 'Latent Space' Decoding

# %%
decoded_imgs = decoder.predict(encoded_imgs)

decoded_imgs.shape
# Out:
# 313/313 [==============================] - 0s 1ms/step
# (10000, 784)

# %% [markdown]
# # VI. Visualization

# %% [markdown]
# > ## 1) decoder - 'decoder_imgs'

# %%
import matplotlib.pyplot as plt

n = 10

plt.figure(figsize = (20, 4))
for i in range(n):

    ax = plt.subplot(2, n, i + 1)
    plt.imshow(X_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# > ## 2) Latent Space - 'encoded_imgs'

# %%
from mpl_toolkits.mplot3d import Axes3D
from pylab import rcParams

rcParams['figure.figsize'] = (10, 10)

fig = plt.figure(1)
ax = Axes3D(fig)

xs = encoded_imgs[:80, 0]
ys = encoded_imgs[:80, 1]
zs = encoded_imgs[:80, 2]

color = ['green', 'tomato', 'blue', 'lime', 'white',
         'gold', 'skyblue', 'violet', 'pink', 'yellow']

for x, y, z, label in zip(xs, ys, zs, y_test):
    col = color[int(label)]
    ax.text(x, y, z, label, backgroundcolor = col)
    
ax.set_xlim(xs.min(), xs.max())
ax.set_ylim(ys.min(), ys.max())
ax.set_zlim(zs.min(), zs.max())

plt.show()

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
