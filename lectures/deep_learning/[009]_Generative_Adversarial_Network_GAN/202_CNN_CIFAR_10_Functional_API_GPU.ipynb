# %% [markdown]
# # CIFAR 10 - Functional API Modeling
#
# * Categorical Classification

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# * import Tensorflow

# %%
import tensorflow

tensorflow.__version__
# Out:
# '2.9.2'

# %% [markdown]
# # I. CIFAR 10 Data_Set Load & Review

# %% [markdown]
# > ## 1) Load CIFAR 10 Data_Set

# %%
from tensorflow.keras.datasets import cifar10

(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step

# %% [markdown]
# * Train_Data Information

# %%
print(len(X_train))
print(X_train.shape)

print(len(y_train))
print(y_train[0:5])
# Out:
# 50000
# (50000, 32, 32, 3)
# 50000
# [[6]
#  [9]
#  [9]
#  [4]
#  [1]]

# %% [markdown]
# * Test_Data Information

# %%
print(len(X_test))
print(X_test.shape)

print(len(y_test))
print(y_test[0:5])
# Out:
# 10000
# (10000, 32, 32, 3)
# 10000
# [[3]
#  [8]
#  [8]
#  [0]
#  [6]]

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Normalization

# %%
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %% [markdown]
# > ## 2) One Hot Encoding

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# > ## 3) train_test_split( )
#
# * Train(40,000) vs. Validation(10,000)

# %%
from sklearn.model_selection import train_test_split 

X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train,
                                                      test_size = 0.2,
                                                      random_state = 2045)

X_train.shape, y_train.shape, X_valid.shape, y_valid.shape
# Out:
# ((40000, 32, 32, 3), (40000, 10), (10000, 32, 32, 3), (10000, 10))

# %% [markdown]
# # III. Keras Functional API Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * 모델 신경망 구조 정의

# %%
# %%time

from tensorflow.keras import models
from tensorflow.keras import layers

input_img = layers.Input((32, 32, 3))

x = layers.Conv2D(filters=32, kernel_size=(3,3), strides=(1,1), padding='valid')(input_img)
x = layers.ReLU()(x)

x = layers.MaxPool2D(pool_size=(2,2))(x)

x = layers.Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), padding='valid')(x)
x = layers.ReLU()(x)

x = layers.MaxPool2D(pool_size=(2,2))(x)

x = layers.Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), padding='valid')(x)
x = layers.ReLU()(x)


x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(64)(x)
x = layers.ReLU()(x)

x = layers.Dense(10)(x)
output_y_hat = layers.Activation('softmax')(x)

CIFAR = models.Model(input_img, output_y_hat)
# Out:
# CPU times: user 760 ms, sys: 798 ms, total: 1.56 s
# Wall time: 4.65 s

# %% [markdown]
# * 모델 구조 확인

# %%
CIFAR.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  re_lu (ReLU)                (None, 30, 30, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  re_lu_1 (ReLU)              (None, 13, 13, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 64)          36928
#
#  re_lu_2 (ReLU)              (None, 4, 4, 64)          0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense (Dense)               (None, 64)                65600
#
#  re_lu_3 (ReLU)              (None, 64)                0
#
#  dense_1 (Dense)             (None, 10)                650
#
#  activation (Activation)     (None, 10)                0
#
# =================================================================
# Total params: 122,570
# Trainable params: 122,570
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
CIFAR.compile(loss = 'categorical_crossentropy',
              optimizer = 'adam',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 5분

# %%
# %%time

Hist_CIFAR = CIFAR.fit(X_train, y_train,
                       epochs = 100,
                       batch_size = 128,
                       validation_data = (X_valid, y_valid))
# Out:
# Epoch 1/100
# 313/313 [==============================] - 10s 8ms/step - loss: 1.7683 - accuracy: 0.3459 - val_loss: 1.4955 - val_accuracy: 0.4607
# Epoch 2/100
# 313/313 [==============================] - 2s 7ms/step - loss: 1.4142 - accuracy: 0.4866 - val_loss: 1.2846 - val_accuracy: 0.5385
# Epoch 3/100
# 313/313 [==============================] - 2s 7ms/step - loss: 1.2673 - accuracy: 0.5448 - val_loss: 1.1406 - val_accuracy: 0.5950
# Epoch 4/100
# 313/313 [==============================] - 2s 7ms/step - loss: 1.1732 - accuracy: 0.5811 - val_loss: 1.0839 - val_accuracy: 0.6138
# Epoch 5/100
# 313/313 [==============================] - 2s 7ms/step - loss: 1.1075 - accuracy: 0.6080 - val_loss: 1.0389 - val_accuracy: 0.6327
# Epoch 6/100
# 313/313 [==============================] - 2s 7ms/step - loss: 1.0537 - accuracy: 0.6291 - val_loss: 0.9633 - val_accuracy: 0.6591
# Epoch 7/100
# 313/313 [==============================] - 2s 7ms/step - loss: 1.0105 - accuracy: 0.6421 - val_loss: 0.9617 - val_accuracy: 0.6542
# Epoch 8/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.9685 - accuracy: 0.6568 - val_loss: 0.9214 - val_accuracy: 0.6753
# Epoch 9/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.9382 - accuracy: 0.6708 - val_loss: 0.8946 - val_accuracy: 0.6860
# Epoch 10/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.9060 - accuracy: 0.6802 - val_loss: 0.8670 - val_accuracy: 0.6931
# Epoch 11/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.8840 - accuracy: 0.6866 - val_loss: 0.8747 - val_accuracy: 0.6955
# Epoch 12/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.8556 - accuracy: 0.6951 - val_loss: 0.8853 - val_accuracy: 0.6900
# Epoch 13/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.8362 - accuracy: 0.7069 - val_loss: 0.8533 - val_accuracy: 0.6998
# Epoch 14/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.8168 - accuracy: 0.7119 - val_loss: 0.8149 - val_accuracy: 0.7099
# Epoch 15/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.7960 - accuracy: 0.7189 - val_loss: 0.8272 - val_accuracy: 0.7121
# Epoch 16/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.7840 - accuracy: 0.7254 - val_loss: 0.7745 - val_accuracy: 0.7318
# Epoch 17/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.7568 - accuracy: 0.7334 - val_loss: 0.7828 - val_accuracy: 0.7263
# Epoch 18/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.7499 - accuracy: 0.7340 - val_loss: 0.8296 - val_accuracy: 0.7132
# Epoch 19/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.7350 - accuracy: 0.7402 - val_loss: 0.7606 - val_accuracy: 0.7322
# Epoch 20/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.7208 - accuracy: 0.7438 - val_loss: 0.7418 - val_accuracy: 0.7446
# Epoch 21/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.7110 - accuracy: 0.7490 - val_loss: 0.7352 - val_accuracy: 0.7432
# Epoch 22/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.6902 - accuracy: 0.7563 - val_loss: 0.7323 - val_accuracy: 0.7461
# Epoch 23/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.6877 - accuracy: 0.7557 - val_loss: 0.7545 - val_accuracy: 0.7378
# Epoch 24/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.6695 - accuracy: 0.7637 - val_loss: 0.7413 - val_accuracy: 0.7424
# Epoch 25/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.6635 - accuracy: 0.7652 - val_loss: 0.7415 - val_accuracy: 0.7409
# Epoch 26/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.6432 - accuracy: 0.7724 - val_loss: 0.7141 - val_accuracy: 0.7523
# Epoch 27/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.6424 - accuracy: 0.7733 - val_loss: 0.7180 - val_accuracy: 0.7551
# Epoch 28/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.6285 - accuracy: 0.7774 - val_loss: 0.7106 - val_accuracy: 0.7568
# Epoch 29/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.6211 - accuracy: 0.7810 - val_loss: 0.7346 - val_accuracy: 0.7440
# Epoch 30/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.6175 - accuracy: 0.7793 - val_loss: 0.7184 - val_accuracy: 0.7593
# Epoch 31/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.6098 - accuracy: 0.7854 - val_loss: 0.7363 - val_accuracy: 0.7467
# Epoch 32/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5965 - accuracy: 0.7881 - val_loss: 0.7127 - val_accuracy: 0.7582
# Epoch 33/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5852 - accuracy: 0.7924 - val_loss: 0.7246 - val_accuracy: 0.7537
# Epoch 34/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.5884 - accuracy: 0.7907 - val_loss: 0.7387 - val_accuracy: 0.7479
# Epoch 35/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.5771 - accuracy: 0.7928 - val_loss: 0.7148 - val_accuracy: 0.7553
# Epoch 36/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5705 - accuracy: 0.7981 - val_loss: 0.7034 - val_accuracy: 0.7600
# Epoch 37/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5566 - accuracy: 0.8018 - val_loss: 0.7298 - val_accuracy: 0.7532
# Epoch 38/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5519 - accuracy: 0.8034 - val_loss: 0.7293 - val_accuracy: 0.7583
# Epoch 39/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5523 - accuracy: 0.8057 - val_loss: 0.7350 - val_accuracy: 0.7537
# Epoch 40/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5482 - accuracy: 0.8043 - val_loss: 0.7079 - val_accuracy: 0.7617
# Epoch 41/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5328 - accuracy: 0.8115 - val_loss: 0.7199 - val_accuracy: 0.7608
# Epoch 42/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5277 - accuracy: 0.8095 - val_loss: 0.7114 - val_accuracy: 0.7589
# Epoch 43/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5262 - accuracy: 0.8121 - val_loss: 0.7254 - val_accuracy: 0.7531
# Epoch 44/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5194 - accuracy: 0.8144 - val_loss: 0.7205 - val_accuracy: 0.7567
# Epoch 45/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5139 - accuracy: 0.8166 - val_loss: 0.7085 - val_accuracy: 0.7638
# Epoch 46/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5131 - accuracy: 0.8186 - val_loss: 0.7061 - val_accuracy: 0.7661
# Epoch 47/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5079 - accuracy: 0.8193 - val_loss: 0.7094 - val_accuracy: 0.7618
# Epoch 48/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4949 - accuracy: 0.8229 - val_loss: 0.7293 - val_accuracy: 0.7533
# Epoch 49/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4921 - accuracy: 0.8237 - val_loss: 0.7480 - val_accuracy: 0.7507
# Epoch 50/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4872 - accuracy: 0.8244 - val_loss: 0.7326 - val_accuracy: 0.7573
# Epoch 51/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4884 - accuracy: 0.8234 - val_loss: 0.7111 - val_accuracy: 0.7634
# Epoch 52/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4719 - accuracy: 0.8289 - val_loss: 0.7204 - val_accuracy: 0.7621
# Epoch 53/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4814 - accuracy: 0.8277 - val_loss: 0.7243 - val_accuracy: 0.7578
# Epoch 54/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4727 - accuracy: 0.8280 - val_loss: 0.7131 - val_accuracy: 0.7609
# Epoch 55/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4705 - accuracy: 0.8307 - val_loss: 0.7208 - val_accuracy: 0.7684
# Epoch 56/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4701 - accuracy: 0.8292 - val_loss: 0.7175 - val_accuracy: 0.7610
# Epoch 57/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4526 - accuracy: 0.8377 - val_loss: 0.7144 - val_accuracy: 0.7631
# Epoch 58/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4573 - accuracy: 0.8352 - val_loss: 0.7552 - val_accuracy: 0.7580
# Epoch 59/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4557 - accuracy: 0.8374 - val_loss: 0.7264 - val_accuracy: 0.7610
# Epoch 60/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4529 - accuracy: 0.8364 - val_loss: 0.7275 - val_accuracy: 0.7608
# Epoch 61/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4461 - accuracy: 0.8399 - val_loss: 0.7271 - val_accuracy: 0.7637
# Epoch 62/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4419 - accuracy: 0.8400 - val_loss: 0.7436 - val_accuracy: 0.7595
# Epoch 63/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4369 - accuracy: 0.8405 - val_loss: 0.7418 - val_accuracy: 0.7618
# Epoch 64/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4313 - accuracy: 0.8453 - val_loss: 0.7389 - val_accuracy: 0.7573
# Epoch 65/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4381 - accuracy: 0.8428 - val_loss: 0.7413 - val_accuracy: 0.7621
# Epoch 66/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4236 - accuracy: 0.8467 - val_loss: 0.7468 - val_accuracy: 0.7586
# Epoch 67/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4220 - accuracy: 0.8475 - val_loss: 0.7397 - val_accuracy: 0.7621
# Epoch 68/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4264 - accuracy: 0.8439 - val_loss: 0.7735 - val_accuracy: 0.7534
# Epoch 69/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4247 - accuracy: 0.8457 - val_loss: 0.7277 - val_accuracy: 0.7655
# Epoch 70/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4203 - accuracy: 0.8487 - val_loss: 0.7539 - val_accuracy: 0.7633
# Epoch 71/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4251 - accuracy: 0.8456 - val_loss: 0.7716 - val_accuracy: 0.7586
# Epoch 72/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4089 - accuracy: 0.8521 - val_loss: 0.7482 - val_accuracy: 0.7618
# Epoch 73/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4142 - accuracy: 0.8500 - val_loss: 0.7254 - val_accuracy: 0.7638
# Epoch 74/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4125 - accuracy: 0.8518 - val_loss: 0.7324 - val_accuracy: 0.7640
# Epoch 75/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4117 - accuracy: 0.8532 - val_loss: 0.7453 - val_accuracy: 0.7646
# Epoch 76/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4091 - accuracy: 0.8508 - val_loss: 0.7668 - val_accuracy: 0.7608
# Epoch 77/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4132 - accuracy: 0.8511 - val_loss: 0.7373 - val_accuracy: 0.7664
# Epoch 78/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3951 - accuracy: 0.8583 - val_loss: 0.7689 - val_accuracy: 0.7601
# Epoch 79/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3982 - accuracy: 0.8571 - val_loss: 0.7712 - val_accuracy: 0.7574
# Epoch 80/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3928 - accuracy: 0.8567 - val_loss: 0.7493 - val_accuracy: 0.7664
# Epoch 81/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3935 - accuracy: 0.8586 - val_loss: 0.7804 - val_accuracy: 0.7578
# Epoch 82/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3933 - accuracy: 0.8555 - val_loss: 0.7509 - val_accuracy: 0.7632
# Epoch 83/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3988 - accuracy: 0.8550 - val_loss: 0.7600 - val_accuracy: 0.7626
# Epoch 84/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3820 - accuracy: 0.8605 - val_loss: 0.7636 - val_accuracy: 0.7643
# Epoch 85/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3845 - accuracy: 0.8601 - val_loss: 0.7650 - val_accuracy: 0.7584
# Epoch 86/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3842 - accuracy: 0.8610 - val_loss: 0.7776 - val_accuracy: 0.7608
# Epoch 87/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3829 - accuracy: 0.8622 - val_loss: 0.7742 - val_accuracy: 0.7616
# Epoch 88/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.3812 - accuracy: 0.8600 - val_loss: 0.7931 - val_accuracy: 0.7518
# Epoch 89/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3842 - accuracy: 0.8594 - val_loss: 0.7839 - val_accuracy: 0.7590
# Epoch 90/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3732 - accuracy: 0.8654 - val_loss: 0.7778 - val_accuracy: 0.7549
# Epoch 91/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3711 - accuracy: 0.8665 - val_loss: 0.7577 - val_accuracy: 0.7656
# Epoch 92/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3700 - accuracy: 0.8666 - val_loss: 0.7638 - val_accuracy: 0.7642
# Epoch 93/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3772 - accuracy: 0.8635 - val_loss: 0.7969 - val_accuracy: 0.7600
# Epoch 94/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3635 - accuracy: 0.8683 - val_loss: 0.7659 - val_accuracy: 0.7648
# Epoch 95/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3686 - accuracy: 0.8669 - val_loss: 0.7926 - val_accuracy: 0.7600
# Epoch 96/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3661 - accuracy: 0.8687 - val_loss: 0.7670 - val_accuracy: 0.7670
# Epoch 97/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3646 - accuracy: 0.8680 - val_loss: 0.7912 - val_accuracy: 0.7608
# Epoch 98/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3662 - accuracy: 0.8671 - val_loss: 0.7715 - val_accuracy: 0.7644
# Epoch 99/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3612 - accuracy: 0.8680 - val_loss: 0.7814 - val_accuracy: 0.7624
# Epoch 100/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3601 - accuracy: 0.8704 - val_loss: 0.8413 - val_accuracy: 0.7497
# CPU times: user 3min 26s, sys: 18.4 s, total: 3min 44s
# Wall time: 4min 24s

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_CIFAR.history['loss']) + 1)

plt.figure(figsize = (15, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, Hist_CIFAR.history['loss'], 'b-')
plt.plot(epochs, Hist_CIFAR.history['val_loss'], 'r--')
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(epochs, Hist_CIFAR.history['accuracy'], 'b-')
plt.plot(epochs, Hist_CIFAR.history['val_accuracy'], 'r--')
plt.title('Training & Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'])
plt.grid()

plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = CIFAR.evaluate(X_test, y_test, verbose = 0)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# Loss = 0.84585
# Accuracy = 0.75040

# %% [markdown]
# # IV. 성능평가

# %% [markdown]
# > ## 1) Label Name 지정

# %%
import numpy as np

CLASSES = np.array(['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 
                    'Dog', 'Frog', 'Horse', 'Ship', 'Truck'])

preds = CIFAR.predict(X_test, verbose = 0)
preds_single = CLASSES[np.argmax(preds, axis = -1)]
actual_single = CLASSES[np.argmax(y_test, axis = -1)]

# %% [markdown]
# > ## 2) 비교 시각화

# %%
import matplotlib.pyplot as plt

n_to_show = 10
indices = np.random.choice(range(len(X_test)), n_to_show)

fig = plt.figure(figsize = (15, 3))
fig.subplots_adjust(hspace = 0.4, wspace = 0.4)

for i, idx in enumerate(indices):
    img = X_test[idx]
    ax = fig.add_subplot(1, n_to_show, i + 1)
    ax.axis('off')
    ax.text(0.5, -0.35, 
            'Pred = ' + str(preds_single[idx]), 
            fontsize = 10, 
            ha = 'center', 
            transform = ax.transAxes) 
    ax.text(0.5, -0.7, 
            'Act = ' + str(actual_single[idx]), 
            fontsize = 10, 
            ha = 'center', 
            transform = ax.transAxes)
    ax.imshow(img)

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
