# %% [markdown]
# # 사전 학습된 CNN(VGG-16)을 이용한 Feature Extraction
# ## VGG-16 Model
# * University of Oxford - Visual Geometry Group
# * 2014 ILSVRC 2nd Model
# * ImageNet Large Scale Visual Recognition Challenge (ILSVRC)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# * Import TensorFlow

# %%
import tensorflow as tf

tf.__version__
# Out:
# '2.9.2'

# %% [markdown]
# # I. wget From Github
# * 'dogs_and_cats_small.zip' 파일 다운로드

# %%
# !wget https://raw.githubusercontent.com/rusita-ai/pyData/master/dogs_and_cats_small.zip
# Out:
# --2023-01-26 01:39:47--  https://raw.githubusercontent.com/rusita-ai/pyData/master/dogs_and_cats_small.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 90618980 (86M) [application/zip]
# Saving to: ‘dogs_and_cats_small.zip’
#
# dogs_and_cats_small 100%[===================>]  86.42M   190MB/s    in 0.5s
#
# 2023-01-26 01:39:54 (190 MB/s) - ‘dogs_and_cats_small.zip’ saved [90618980/90618980]

# %% [markdown]
# * 다운로드 결과 확인

# %%
# !ls -l
# Out:
# total 88500
# -rw-r--r-- 1 root root 90618980 Jan 26 01:39 dogs_and_cats_small.zip
# drwxr-xr-x 1 root root     4096 Jan 24 14:38 sample_data

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Unzip 'dogs_and_cats_small.zip'

# %%
# !unzip -q /content/dogs_and_cats_small.zip

# %% [markdown]
# * 학습 데이터 확인

# %%
# !ls -l
# Out:
# total 88512
# -rw-r--r-- 1 root root 90618980 Jan 26 01:39 dogs_and_cats_small.zip
# drwxr-xr-x 1 root root     4096 Jan 24 14:38 sample_data
# drwxr-xr-x 4 root root     4096 Jan 26 01:39 test
# drwxr-xr-x 4 root root     4096 Jan 26 01:39 train
# drwxr-xr-x 4 root root     4096 Jan 26 01:39 validation

# %% [markdown]
# > ## 2) Image_File Directory Setting

# %% [markdown]
# * train_dir
# * valid_dir
# * test_dir

# %%
train_dir = 'train'
valid_dir = 'validation'
test_dir = 'test'

# %% [markdown]
# # III. Import VGG-16 Model

# %% [markdown]
# > ## 1) conv_base

# %%
from tensorflow.keras.applications import VGG16

conv_base = VGG16(weights = 'imagenet',
                  include_top = False,
                  input_shape = (150, 150, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step

# %% [markdown]
# > ## 2) Model Information

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # IV. Feature Extraction

# %% [markdown]
# > ## 1) 특징추출 함수 정의 : extract_feature( )
# * conv_base.predict( )

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

datagen = ImageDataGenerator(rescale = 1./255)

batch_size = 20

def extract_features(directory, sample_count):
    features = np.zeros(shape = (sample_count, 4, 4, 512))
    labels = np.zeros(shape = (sample_count))
    
    generator = datagen.flow_from_directory(directory,
                                            target_size = (150, 150),
                                            batch_size = batch_size,
                                            class_mode = 'binary')
    
    i = 0
    for inputs_batch, labels_batch in generator:
        features_batch = conv_base.predict(inputs_batch, verbose = 0)
        features[i * batch_size : (i + 1) * batch_size] = features_batch
        labels[i * batch_size : (i + 1) * batch_size] = labels_batch
        i += 1
        if i * batch_size >= sample_count:
            break
    return features, labels

# %% [markdown]
# > ## 2) 특징추출 함수 적용
# * train_dir
# * valid_dir
# * test_dir

# %% [markdown]
# * 약 1분

# %%
# %%time

train_features, train_labels = extract_features(train_dir, 2000)
valid_features, valid_labels = extract_features(valid_dir, 1000)
test_features, test_labels = extract_features(test_dir, 1000)
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.
# CPU times: user 30.6 s, sys: 1.36 s, total: 31.9 s
# Wall time: 39.9 s

# %%
train_features.shape, valid_features.shape, test_features.shape
# Out:
# ((2000, 4, 4, 512), (1000, 4, 4, 512), (1000, 4, 4, 512))

# %% [markdown]
# > ## 3) Reshape Features
# * For 'Classification' Network

# %%
train_features = np.reshape(train_features, (2000, 4 * 4 * 512))
valid_features = np.reshape(valid_features, (1000, 4 * 4 * 512))
test_features = np.reshape(test_features, (1000, 4 * 4 * 512))

train_features.shape, valid_features.shape, test_features.shape
# Out:
# ((2000, 8192), (1000, 8192), (1000, 8192))

# %% [markdown]
# # V. Keras DNN Modeling with VGG-16 Featured Data

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * 'Classification' Network Only
# * Dropout Layer

# %%
from tensorflow.keras import models, layers

model = models.Sequential()
model.add(layers.Dense(256, activation = 'relu', input_dim = 4 * 4 * 512))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               2097408
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 2,097,665
# Trainable params: 2,097,665
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
model.compile(loss = 'binary_crossentropy',
              optimizer = 'adam',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 2분

# %%
# %%time

Hist_dandc = model.fit(train_features, train_labels,
                       epochs = 100,
                       batch_size = 20,
                       validation_data = (valid_features, valid_labels))
# Out:
# Epoch 1/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4635 - accuracy: 0.7940 - val_loss: 0.3317 - val_accuracy: 0.8420
# Epoch 2/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2486 - accuracy: 0.8965 - val_loss: 0.2395 - val_accuracy: 0.9000
# Epoch 3/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2018 - accuracy: 0.9190 - val_loss: 0.2859 - val_accuracy: 0.8780
# Epoch 4/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1705 - accuracy: 0.9285 - val_loss: 0.2904 - val_accuracy: 0.8870
# Epoch 5/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1358 - accuracy: 0.9475 - val_loss: 0.4038 - val_accuracy: 0.8580
# Epoch 6/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1196 - accuracy: 0.9550 - val_loss: 0.2902 - val_accuracy: 0.8910
# Epoch 7/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0858 - accuracy: 0.9705 - val_loss: 0.2587 - val_accuracy: 0.9050
# Epoch 8/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0852 - accuracy: 0.9690 - val_loss: 0.2891 - val_accuracy: 0.9020
# Epoch 9/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0704 - accuracy: 0.9730 - val_loss: 0.2749 - val_accuracy: 0.9080
# Epoch 10/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0612 - accuracy: 0.9785 - val_loss: 0.3305 - val_accuracy: 0.9000
# Epoch 11/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0494 - accuracy: 0.9855 - val_loss: 0.2889 - val_accuracy: 0.9080
# Epoch 12/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0407 - accuracy: 0.9865 - val_loss: 0.3698 - val_accuracy: 0.9010
# Epoch 13/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0360 - accuracy: 0.9895 - val_loss: 0.3666 - val_accuracy: 0.8900
# Epoch 14/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0289 - accuracy: 0.9910 - val_loss: 0.3595 - val_accuracy: 0.8940
# Epoch 15/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0259 - accuracy: 0.9920 - val_loss: 0.3549 - val_accuracy: 0.8950
# Epoch 16/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0655 - accuracy: 0.9710 - val_loss: 0.4902 - val_accuracy: 0.8740
# Epoch 17/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0496 - accuracy: 0.9840 - val_loss: 0.3667 - val_accuracy: 0.9040
# Epoch 18/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0397 - accuracy: 0.9840 - val_loss: 0.3641 - val_accuracy: 0.9090
# Epoch 19/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0232 - accuracy: 0.9925 - val_loss: 0.3936 - val_accuracy: 0.9030
# Epoch 20/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0170 - accuracy: 0.9950 - val_loss: 0.4669 - val_accuracy: 0.8950
# Epoch 21/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0205 - accuracy: 0.9935 - val_loss: 0.4457 - val_accuracy: 0.9040
# Epoch 22/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0292 - accuracy: 0.9890 - val_loss: 0.4269 - val_accuracy: 0.8990
# Epoch 23/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 0.9945 - val_loss: 0.5991 - val_accuracy: 0.8780
# Epoch 24/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0344 - accuracy: 0.9865 - val_loss: 0.4320 - val_accuracy: 0.8920
# Epoch 25/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0280 - accuracy: 0.9905 - val_loss: 0.4648 - val_accuracy: 0.8910
# Epoch 26/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0167 - accuracy: 0.9940 - val_loss: 0.4300 - val_accuracy: 0.8970
# Epoch 27/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0193 - accuracy: 0.9930 - val_loss: 0.5631 - val_accuracy: 0.8860
# Epoch 28/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0424 - accuracy: 0.9835 - val_loss: 0.5306 - val_accuracy: 0.8860
# Epoch 29/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0531 - accuracy: 0.9805 - val_loss: 0.4541 - val_accuracy: 0.8970
# Epoch 30/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0520 - accuracy: 0.9825 - val_loss: 0.3431 - val_accuracy: 0.9010
# Epoch 31/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0332 - accuracy: 0.9885 - val_loss: 0.4322 - val_accuracy: 0.9020
# Epoch 32/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0253 - accuracy: 0.9920 - val_loss: 0.4971 - val_accuracy: 0.8940
# Epoch 33/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0279 - accuracy: 0.9900 - val_loss: 0.4633 - val_accuracy: 0.8960
# Epoch 34/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0193 - accuracy: 0.9940 - val_loss: 0.5045 - val_accuracy: 0.8980
# Epoch 35/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0134 - accuracy: 0.9960 - val_loss: 0.4591 - val_accuracy: 0.8980
# Epoch 36/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0077 - accuracy: 0.9985 - val_loss: 0.5008 - val_accuracy: 0.8920
# Epoch 37/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0068 - accuracy: 0.9980 - val_loss: 0.5794 - val_accuracy: 0.9000
# Epoch 38/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0172 - accuracy: 0.9935 - val_loss: 0.4726 - val_accuracy: 0.8970
# Epoch 39/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0379 - accuracy: 0.9855 - val_loss: 0.6628 - val_accuracy: 0.8730
# Epoch 40/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0327 - accuracy: 0.9855 - val_loss: 0.4787 - val_accuracy: 0.9010
# Epoch 41/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0147 - accuracy: 0.9940 - val_loss: 0.4576 - val_accuracy: 0.9050
# Epoch 42/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0197 - accuracy: 0.9940 - val_loss: 0.5612 - val_accuracy: 0.8970
# Epoch 43/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0199 - accuracy: 0.9940 - val_loss: 0.4313 - val_accuracy: 0.9030
# Epoch 44/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0302 - accuracy: 0.9885 - val_loss: 0.4957 - val_accuracy: 0.9090
# Epoch 45/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0225 - accuracy: 0.9935 - val_loss: 0.5059 - val_accuracy: 0.8830
# Epoch 46/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0349 - accuracy: 0.9860 - val_loss: 0.4288 - val_accuracy: 0.9000
# Epoch 47/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0198 - accuracy: 0.9915 - val_loss: 0.5092 - val_accuracy: 0.9070
# Epoch 48/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0177 - accuracy: 0.9930 - val_loss: 0.5254 - val_accuracy: 0.9020
# Epoch 49/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0120 - accuracy: 0.9960 - val_loss: 0.5744 - val_accuracy: 0.9010
# Epoch 50/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0163 - accuracy: 0.9955 - val_loss: 0.4948 - val_accuracy: 0.9010
# Epoch 51/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0118 - accuracy: 0.9960 - val_loss: 0.5943 - val_accuracy: 0.9010
# Epoch 52/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0162 - accuracy: 0.9945 - val_loss: 0.6277 - val_accuracy: 0.8940
# Epoch 53/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0162 - accuracy: 0.9945 - val_loss: 0.5463 - val_accuracy: 0.8850
# Epoch 54/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0077 - accuracy: 0.9975 - val_loss: 0.5347 - val_accuracy: 0.9030
# Epoch 55/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0093 - accuracy: 0.9970 - val_loss: 0.6071 - val_accuracy: 0.9000
# Epoch 56/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0110 - accuracy: 0.9970 - val_loss: 0.5995 - val_accuracy: 0.9010
# Epoch 57/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0135 - accuracy: 0.9955 - val_loss: 0.5316 - val_accuracy: 0.9070
# Epoch 58/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0111 - accuracy: 0.9960 - val_loss: 0.6913 - val_accuracy: 0.9000
# Epoch 59/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0132 - accuracy: 0.9965 - val_loss: 0.6275 - val_accuracy: 0.8970
# Epoch 60/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0140 - accuracy: 0.9955 - val_loss: 0.7291 - val_accuracy: 0.8990
# Epoch 61/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0428 - accuracy: 0.9845 - val_loss: 0.6666 - val_accuracy: 0.8950
# Epoch 62/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0450 - accuracy: 0.9845 - val_loss: 0.5233 - val_accuracy: 0.8880
# Epoch 63/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0203 - accuracy: 0.9910 - val_loss: 0.5574 - val_accuracy: 0.8950
# Epoch 64/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0118 - accuracy: 0.9955 - val_loss: 0.6521 - val_accuracy: 0.8940
# Epoch 65/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0244 - accuracy: 0.9910 - val_loss: 0.9665 - val_accuracy: 0.8740
# Epoch 66/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0190 - accuracy: 0.9930 - val_loss: 0.7149 - val_accuracy: 0.9060
# Epoch 67/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0084 - accuracy: 0.9985 - val_loss: 0.7245 - val_accuracy: 0.9010
# Epoch 68/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0074 - accuracy: 0.9980 - val_loss: 0.8304 - val_accuracy: 0.8990
# Epoch 69/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0158 - accuracy: 0.9940 - val_loss: 0.6301 - val_accuracy: 0.8960
# Epoch 70/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 0.9975 - val_loss: 0.7707 - val_accuracy: 0.8890
# Epoch 71/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0161 - accuracy: 0.9925 - val_loss: 0.8991 - val_accuracy: 0.8910
# Epoch 72/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0133 - accuracy: 0.9945 - val_loss: 0.6678 - val_accuracy: 0.9030
# Epoch 73/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0107 - accuracy: 0.9965 - val_loss: 0.7168 - val_accuracy: 0.8950
# Epoch 74/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0096 - accuracy: 0.9955 - val_loss: 0.6718 - val_accuracy: 0.9020
# Epoch 75/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0091 - accuracy: 0.9975 - val_loss: 0.6814 - val_accuracy: 0.9050
# Epoch 76/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0182 - accuracy: 0.9940 - val_loss: 0.6083 - val_accuracy: 0.9010
# Epoch 77/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0122 - accuracy: 0.9960 - val_loss: 0.6047 - val_accuracy: 0.8970
# Epoch 78/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 0.9980 - val_loss: 0.7918 - val_accuracy: 0.8940
# Epoch 79/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0148 - accuracy: 0.9940 - val_loss: 0.5620 - val_accuracy: 0.8990
# Epoch 80/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0198 - accuracy: 0.9920 - val_loss: 0.7115 - val_accuracy: 0.8830
# Epoch 81/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0108 - accuracy: 0.9970 - val_loss: 0.7184 - val_accuracy: 0.8980
# Epoch 82/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0085 - accuracy: 0.9965 - val_loss: 0.6750 - val_accuracy: 0.8990
# Epoch 83/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0108 - accuracy: 0.9950 - val_loss: 0.7529 - val_accuracy: 0.8970
# Epoch 84/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0157 - accuracy: 0.9940 - val_loss: 0.6131 - val_accuracy: 0.9050
# Epoch 85/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0187 - accuracy: 0.9930 - val_loss: 0.6664 - val_accuracy: 0.8990
# Epoch 86/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0185 - accuracy: 0.9945 - val_loss: 0.7831 - val_accuracy: 0.9050
# Epoch 87/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0257 - accuracy: 0.9890 - val_loss: 0.6560 - val_accuracy: 0.8960
# Epoch 88/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0158 - accuracy: 0.9945 - val_loss: 0.6313 - val_accuracy: 0.9030
# Epoch 89/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0175 - accuracy: 0.9945 - val_loss: 0.6505 - val_accuracy: 0.9030
# Epoch 90/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0123 - accuracy: 0.9960 - val_loss: 0.7245 - val_accuracy: 0.8960
# Epoch 91/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0208 - accuracy: 0.9940 - val_loss: 0.7350 - val_accuracy: 0.9030
# Epoch 92/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0103 - accuracy: 0.9955 - val_loss: 0.8686 - val_accuracy: 0.8930
# Epoch 93/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0121 - accuracy: 0.9955 - val_loss: 0.8683 - val_accuracy: 0.8920
# Epoch 94/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0197 - accuracy: 0.9935 - val_loss: 0.7706 - val_accuracy: 0.8940
# Epoch 95/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0305 - accuracy: 0.9905 - val_loss: 0.6713 - val_accuracy: 0.9040
# Epoch 96/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0087 - accuracy: 0.9955 - val_loss: 0.7254 - val_accuracy: 0.8970
# Epoch 97/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0057 - accuracy: 0.9975 - val_loss: 0.9297 - val_accuracy: 0.8850
# Epoch 98/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0093 - accuracy: 0.9980 - val_loss: 0.6334 - val_accuracy: 0.9030
# Epoch 99/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0084 - accuracy: 0.9975 - val_loss: 0.7716 - val_accuracy: 0.9020
# Epoch 100/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 0.9985 - val_loss: 0.9818 - val_accuracy: 0.8910
# CPU times: user 42.3 s, sys: 3.65 s, total: 45.9 s
# Wall time: 41.5 s

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_dandc.history['loss']) + 1)

plt.figure(figsize = (15, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, Hist_dandc.history['loss'], 'b-')
plt.plot(epochs, Hist_dandc.history['val_loss'], 'r--')
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(epochs, Hist_dandc.history['accuracy'], 'b-')
plt.plot(epochs, Hist_dandc.history['val_accuracy'], 'r--')
plt.title('Training & Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'])
plt.grid()

plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = model.evaluate(test_features, test_labels, verbose = 0)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# Loss = 0.98170
# Accuracy = 0.88600

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
